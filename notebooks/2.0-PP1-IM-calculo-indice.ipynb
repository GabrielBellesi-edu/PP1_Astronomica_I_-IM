# %%
import os
os.getcwd()

# %%
# # Análisis de Índice de Masa de Meteoritos

# Este notebook utiliza la clase `MeteoriteMassAnalyzer` para calcular el índice de masa de meteoritos usando el método estándar de regresión log-log.

# **Ubicación:** `notebooks/2.0-PP1-IM-calculo-indice.ipynb`

# ## 1. Configuración Inicial


# Importar librerías necesarias
import sys
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# Configurar matplotlib para mostrar gráficos en la notebook
# %matplotlib inline
plt.style.use('default')
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 10

# Agregar el directorio raíz del proyecto al path para importar el módulo
project_root = os.path.abspath('..')  # Subir un nivel desde notebooks/
if project_root not in sys.path:
    sys.path.append(project_root)

# Importar la clase principal
from calculo.calcular_indice_masa import MeteoriteMassAnalyzer

print("✓ Librerías importadas correctamente")
print(f"✓ Directorio del proyecto: {project_root}")

# %% [markdown]
# ## 2. Inicialización del Analizador

# %%
# Crear instancia del analizador
analyzer = MeteoriteMassAnalyzer(project_root=project_root)

# %% [markdown]
# ## 3. Exploración Inicial de Datos

# %%
# Cargar datos para exploración
print("Cargando datos para exploración...")
amplitudes, df = analyzer.load_data(file_type='csv')

if amplitudes is not None:
    print(f"\n📊 ESTADÍSTICAS BÁSICAS:")
    print(f"   • Total de registros: {len(amplitudes)}")
    print(f"   • Amplitud mínima: {amplitudes.min():.2f}")
    print(f"   • Amplitud máxima: {amplitudes.max():.2f}")
    print(f"   • Amplitud promedio: {amplitudes.mean():.2f}")
    print(f"   • Desviación estándar: {amplitudes.std():.2f}")
    
    # Mostrar información temporal si está disponible
    if df is not None and 'datetime' in df.columns:
        print(f"\n📅 INFORMACIÓN TEMPORAL:")
        print(f"   • Fecha inicial: {df['datetime'].min()}")
        print(f"   • Fecha final: {df['datetime'].max()}")
        print(f"   • Período total: {(df['datetime'].max() - df['datetime'].min()).days} días")
    
    # Crear histograma básico
    plt.figure(figsize=(14, 5))
    
    plt.subplot(1, 2, 1)
    plt.hist(amplitudes, bins=50, alpha=0.7, color='skyblue', edgecolor='black')
    plt.xlabel('Amplitud')
    plt.ylabel('Frecuencia')
    plt.title('Distribución de Amplitudes')
    plt.grid(True, alpha=0.3)
    
    plt.subplot(1, 2, 2)
    plt.hist(amplitudes, bins=50, alpha=0.7, color='lightcoral', edgecolor='black')
    plt.xlabel('Amplitud')
    plt.ylabel('Frecuencia')
    plt.title('Distribución de Amplitudes (Escala Log)')
    plt.yscale('log')
    plt.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()
else:
    print("❌ Error al cargar los datos")

# %% [markdown]
# ## 4. Análisis Básico - Todos los Datos

# %%
print("🔬 ANÁLISIS BÁSICO - TODOS LOS DATOS")
print("="*50)

# Parámetros básicos
basic_results = analyzer.analyze_mass_index(
    file_type='csv',
    period='anual',
    min_amplitude=None,  # Sin filtro de amplitud mínima
    use_binning=False,   # Sin binning
    save_results=True,
    save_plots=True
)

# %% [markdown]
# ## 5. Análisis Comparativo con Diferentes Parámetros

# %% [markdown]
# ### 5.1 Efecto del Filtrado por Amplitud Mínima

# %%
print("🔍 ANÁLISIS: EFECTO DEL FILTRADO POR AMPLITUD MÍNIMA")
print("="*55)

# Diferentes valores de amplitud mínima para comparar
min_amplitudes = [None, 1.0, 2.0, 5.0, 10.0]
amplitude_results = {}

for min_amp in min_amplitudes:
    print(f"\n--- Amplitud mínima: {min_amp if min_amp else 'Sin filtro'} ---")
    
    result = analyzer.analyze_mass_index(
        file_type='csv',
        period='anual',
        min_amplitude=min_amp,
        use_binning=False,
        save_results=False,  # No guardar para comparaciones
        save_plots=True
    )
    
    if result and 'todos_los_datos' in result:
        amplitude_results[f"min_{min_amp if min_amp else 'none'}"] = result['todos_los_datos']

# Crear tabla comparativa
if amplitude_results:
    print("\n📋 TABLA COMPARATIVA - EFECTO DE AMPLITUD MÍNIMA:")
    print("-" * 80)
    print(f"{'Filtro':<12} {'N_datos':<8} {'Índice_s':<10} {'R²':<8} {'P-value':<12}")
    print("-" * 80)
    
    for key, result in amplitude_results.items():
        min_val = key.replace('min_', '').replace('none', 'Sin filtro')
        print(f"{min_val:<12} {result['n_data_points']:<8} "
              f"{result['mass_index']:<10.4f} {result['r_squared']:<8.4f} "
              f"{result['p_value']:<12.2e}")

# %% [markdown]
# ### 5.2 Efecto del Binning Logarítmico

# %%
print("\n🔍 ANÁLISIS: EFECTO DEL BINNING LOGARÍTMICO")
print("="*45)

# Comparar con y sin binning
binning_configs = [
    {'use_binning': False, 'n_bins': 0, 'name': 'Sin binning'},
    {'use_binning': True, 'n_bins': 25, 'name': 'Binning 25'},
    {'use_binning': True, 'n_bins': 50, 'name': 'Binning 50'},
    {'use_binning': True, 'n_bins': 100, 'name': 'Binning 100'}
]

binning_results = {}

for config in binning_configs:
    print(f"\n--- {config['name']} ---")
    
    result = analyzer.analyze_mass_index(
        file_type='csv',
        period='anual',
        min_amplitude=None,
        use_binning=config['use_binning'],
        n_bins=config['n_bins'],
        save_results=False,
        save_plots=False
    )
    
    if result and 'todos_los_datos' in result:
        binning_results[config['name']] = result['todos_los_datos']

# Tabla comparativa binning
if binning_results:
    print("\n📋 TABLA COMPARATIVA - EFECTO DEL BINNING:")
    print("-" * 80)
    print(f"{'Método':<15} {'N_regres':<10} {'Índice_s':<10} {'R²':<8} {'P-value':<12}")
    print("-" * 80)
    
    for name, result in binning_results.items():
        print(f"{name:<15} {result['n_regression_points']:<10} "
              f"{result['mass_index']:<10.4f} {result['r_squared']:<8.4f} "
              f"{result['p_value']:<12.2e}")

# %% [markdown]
# ## 6. Análisis Temporal por Períodos

# %% [markdown]
# ### 6.1 Análisis Mensual

# %%
print("📅 ANÁLISIS TEMPORAL - POR MESES")
print("="*35)

monthly_results = analyzer.analyze_mass_index(
    file_type='csv',
    period='mensual',
    min_amplitude=None,
    use_binning=False,
    save_results=True,
    save_plots=True  # No guardar gráficos individuales para evitar saturación
)

# Crear gráfico resumen mensual
if monthly_results:
    months = []
    mass_indices = []
    r_squared_vals = []
    n_data_points = []
    
    for month, result in monthly_results.items():
        months.append(month)
        mass_indices.append(result['mass_index'])
        r_squared_vals.append(result['r_squared'])
        n_data_points.append(result['n_data_points'])
    
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(16, 10))
    
    # Índice de masa por mes
    ax1.bar(range(len(months)), mass_indices, color='skyblue', alpha=0.7)
    ax1.set_xlabel('Mes')
    ax1.set_ylabel('Índice de Masa (s)')
    ax1.set_title('Índice de Masa por Mes')
    ax1.set_xticks(range(len(months)))
    ax1.set_xticklabels(months, rotation=45)
    ax1.grid(True, alpha=0.3)
    
    # R² por mes
    ax2.bar(range(len(months)), r_squared_vals, color='lightcoral', alpha=0.7)
    ax2.set_xlabel('Mes')
    ax2.set_ylabel('R² (Bondad de Ajuste)')
    ax2.set_title('Calidad del Ajuste por Mes')
    ax2.set_xticks(range(len(months)))
    ax2.set_xticklabels(months, rotation=45)
    ax2.grid(True, alpha=0.3)
    
    # Número de datos por mes
    ax3.bar(range(len(months)), n_data_points, color='lightgreen', alpha=0.7)
    ax3.set_xlabel('Mes')
    ax3.set_ylabel('Número de Datos')
    ax3.set_title('Cantidad de Datos por Mes')
    ax3.set_xticks(range(len(months)))
    ax3.set_xticklabels(months, rotation=45)
    ax3.grid(True, alpha=0.3)
    
    # Tendencia del índice de masa
    ax4.plot(range(len(months)), mass_indices, 'o-', color='purple', linewidth=2, markersize=6)
    ax4.set_xlabel('Mes')
    ax4.set_ylabel('Índice de Masa (s)')
    ax4.set_title('Tendencia Temporal del Índice de Masa')
    ax4.set_xticks(range(len(months)))
    ax4.set_xticklabels(months, rotation=45)
    ax4.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### 6.2 Análisis Trimestral

# %%
print("📅 ANÁLISIS TEMPORAL - POR TRIMESTRES")
print("="*38)

quarterly_results = analyzer.analyze_mass_index(
    file_type='csv',
    period='trimestral',
    min_amplitude=None,
    use_binning=False,
    save_results=True,
    save_plots=False
)

# Mostrar tabla resumen trimestral
if quarterly_results:
    print("\n📋 RESUMEN TRIMESTRAL:")
    print("-" * 70)
    print(f"{'Trimestre':<12} {'N_datos':<8} {'Índice_s':<10} {'R²':<8} {'P-value':<12}")
    print("-" * 70)
    
    for quarter, result in quarterly_results.items():
        print(f"{quarter:<12} {result['n_data_points']:<8} "
              f"{result['mass_index']:<10.4f} {result['r_squared']:<8.4f} "
              f"{result['p_value']:<12.2e}")


"""
# %% [markdown]
# ## 7. Análisis Personalizado Interactivo

# %%
print("🛠️ SECCIÓN DE ANÁLISIS PERSONALIZADO")
print("="*40)
print("Modifica estos parámetros según tus necesidades:")

# Parámetros personalizables
CUSTOM_PARAMS = {
    'file_type': 'csv',           # 'csv' o 'txt'
    'period': 'anual',            # 'anual', 'mensual', 'trimestral', etc.
    'min_amplitude': None,        # None o valor numérico (ej: 2.0)
    'use_binning': False,         # True o False
    'n_bins': 50,                 # Número de bins si use_binning=True
    'save_results': True,         # True o False
    'save_plots': True            # True o False
}

print(f"\nParámetros actuales:")
for param, value in CUSTOM_PARAMS.items():
    print(f"  • {param}: {value}")

print(f"\n¿Quieres ejecutar el análisis con estos parámetros? (Ejecuta la siguiente celda)")

# %%
# EJECUTAR ANÁLISIS PERSONALIZADO
print("🚀 EJECUTANDO ANÁLISIS PERSONALIZADO...")
print("="*45)

custom_results = analyzer.analyze_mass_index(**CUSTOM_PARAMS)

if custom_results:
    print(f"\n✅ Análisis completado exitosamente!")
    print(f"   • {len(custom_results)} período(s) analizado(s)")
    
    # Mostrar resumen de todos los períodos
    if len(custom_results) > 1:
        print(f"\n📊 RESUMEN DE TODOS LOS PERÍODOS:")
        print("-" * 80)
        print(f"{'Período':<15} {'N_datos':<8} {'Índice_s':<10} {'R²':<8} {'Rango_Amp':<15}")
        print("-" * 80)
        
        for period_name, result in custom_results.items():
            amp_range = f"{result['amplitude_range'][0]:.1f}-{result['amplitude_range'][1]:.1f}"
            print(f"{period_name:<15} {result['n_data_points']:<8} "
                  f"{result['mass_index']:<10.4f} {result['r_squared']:<8.4f} {amp_range:<15}")
else:
    print("❌ Error en el análisis personalizado")
"""
"""
# %% [markdown]
# ## 8. Comparación de Métodos (Opcional)

# %%
print("⚖️ COMPARACIÓN DE MÉTODOS")
print("="*30)
print("Comparando diferentes enfoques para el mismo conjunto de datos...")

# Configuraciones para comparar
comparison_configs = [
    {'name': 'Estándar', 'min_amplitude': None, 'use_binning': False},
    {'name': 'Filtrado (min=2)', 'min_amplitude': 2.0, 'use_binning': False},
    {'name': 'Binning 50', 'min_amplitude': None, 'use_binning': True, 'n_bins': 50},
    {'name': 'Filt+Bin', 'min_amplitude': 2.0, 'use_binning': True, 'n_bins': 50}
]

comparison_results = {}

for config in comparison_configs:
    print(f"\n--- Método: {config['name']} ---")
    
    params = {
        'file_type': 'csv',
        'period': 'anual',
        'min_amplitude': config.get('min_amplitude'),
        'use_binning': config.get('use_binning', False),
        'n_bins': config.get('n_bins', 50),
        'save_results': False,
        'save_plots': False
    }
    
    result = analyzer.analyze_mass_index(**params)
    if result and 'todos_los_datos' in result:
        comparison_results[config['name']] = result['todos_los_datos']

# Tabla final de comparación
if comparison_results:
    print(f"\n📋 TABLA COMPARATIVA FINAL:")
    print("=" * 90)
    print(f"{'Método':<15} {'N_datos':<8} {'N_regres':<9} {'Índice_s':<10} {'R²':<8} {'Error_std':<10}")
    print("=" * 90)
    
    for method, result in comparison_results.items():
        print(f"{method:<15} {result['n_data_points']:<8} {result['n_regression_points']:<9} "
              f"{result['mass_index']:<10.4f} {result['r_squared']:<8.4f} {result['std_error']:<10.4f}")
    
    print("=" * 90)
"""
# %% [markdown]
# ## 9. Conclusiones y Próximos Pasos

# %%
print("📝 RESUMEN DEL ANÁLISIS")
print("="*25)

if 'basic_results' in locals() and basic_results:
    main_result = list(basic_results.values())[0]
    print(f"✅ RESULTADO PRINCIPAL:")
    print(f"   • Índice de masa calculado: s = {main_result['mass_index']:.4f}")
    print(f"   • Calidad del ajuste (R²): {main_result['r_squared']:.4f}")
    print(f"   • Número de datos utilizados: {main_result['n_data_points']}")
    print(f"   • Rango de amplitudes: {main_result['amplitude_range'][0]:.2f} - {main_result['amplitude_range'][1]:.2f}")

print(f"\n📂 ARCHIVOS GENERADOS:")
print(f"   • Resultados guardados en: {analyzer.reports_dir}")
print(f"   • Gráficos guardados en: {analyzer.figures_dir}")

# %% [markdown]
# ---
# **Fin del análisis**
# 
# Este notebook proporciona un análisis completo del índice de masa de meteoritos. Los resultados y gráficos se han guardado automáticamente en las carpetas correspondientes del proyecto.
# Out:
# ✓ Librerías importadas correctamente
# ✓ Directorio del proyecto: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM
# Proyecto inicializado:
#   - Raíz del proyecto: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM
#   - Datos: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\data\processed
#   - Reportes: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\reports
#   - Figuras: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\reports\figures
# Cargando datos para exploración...
# Cargando datos desde: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\data\processed\2024_consolidado.csv
# Datos CSV cargados: 961167 filas, 14 columnas
# Columnas disponibles: ['Date', 'Time', 'Rge', 'Ht', 'Vrad', 'delVr', 'Theta', 'Phi0', 'Delphase', 'ant-pair', 'amax', 'Tau', 'vmet', 'snrdb']
# Columna datetime creada exitosamente
#
# 📊 ESTADÍSTICAS BÁSICAS:
#    • Total de registros: 961167
#    • Amplitud mínima: 310.00
#    • Amplitud máxima: 43426.00
#    • Amplitud promedio: 3705.54
#    • Desviación estándar: 4107.82
#
# 📅 INFORMACIÓN TEMPORAL:
#    • Fecha inicial: 2024-01-01 00:02:01.835000
#    • Fecha final: 2024-12-31 23:59:58.229000
#    • Período total: 365 días
# 🔬 ANÁLISIS BÁSICO - TODOS LOS DATOS
# ==================================================
# ============================================================
# INICIANDO ANÁLISIS DE ÍNDICE DE MASA DE METEORITOS
# ============================================================
# Tipo de archivo: CSV
# Período de análisis: anual
#
# Cargando datos desde: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\data\processed\2024_consolidado.csv
# Datos CSV cargados: 961167 filas, 14 columnas
# Columnas disponibles: ['Date', 'Time', 'Rge', 'Ht', 'Vrad', 'delVr', 'Theta', 'Phi0', 'Delphase', 'ant-pair', 'amax', 'Tau', 'vmet', 'snrdb']
# Columna datetime creada exitosamente
# Datos agrupados por anual: 1 períodos
#
# --- Analizando período: 2024 ---
#
# ============================================================
# RESULTADOS DEL ANÁLISIS DE ÍNDICE DE MASA - 2024
# ============================================================
# Índice de masa (s):           2.1561
# Pendiente de regresión:       -1.1561
# Intercepto:                   9.4827
# Coeficiente de correlación:   -0.9499
# R² (bondad de ajuste):        0.9024
# P-value:                      0.00e+00
# Error estándar:               0.0004
# Número de datos originales:   961167
# Puntos usados en regresión:   961167
# Amplitud mínima:              310.00
# Amplitud máxima:              43426.00
# Amplitud promedio:            3705.54
# Binning aplicado:             No
# ============================================================
# ✓ Excelente ajuste de la regresión
# ✓ Índice de masa calculado: s = 2.1561
# Resultados guardados en: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\reports\indice_masa_2024_20250608_013221.txt
# Gráfico guardado como: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\reports\figures\indice_masa_2024_20250608_013230.png
#
# ============================================================
# ANÁLISIS COMPLETADO - 1 períodos procesados
# ============================================================
# 🔍 ANÁLISIS: EFECTO DEL FILTRADO POR AMPLITUD MÍNIMA
# =======================================================
#
# --- Amplitud mínima: Sin filtro ---
# ============================================================
# INICIANDO ANÁLISIS DE ÍNDICE DE MASA DE METEORITOS
# ============================================================
# Tipo de archivo: CSV
# Período de análisis: anual
#
# Cargando datos desde: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\data\processed\2024_consolidado.csv
# Datos CSV cargados: 961167 filas, 14 columnas
# Columnas disponibles: ['Date', 'Time', 'Rge', 'Ht', 'Vrad', 'delVr', 'Theta', 'Phi0', 'Delphase', 'ant-pair', 'amax', 'Tau', 'vmet', 'snrdb']
# Columna datetime creada exitosamente
# Datos agrupados por anual: 1 períodos
#
# --- Analizando período: 2024 ---
#
# ============================================================
# RESULTADOS DEL ANÁLISIS DE ÍNDICE DE MASA - 2024
# ============================================================
# Índice de masa (s):           2.1561
# Pendiente de regresión:       -1.1561
# Intercepto:                   9.4827
# Coeficiente de correlación:   -0.9499
# R² (bondad de ajuste):        0.9024
# P-value:                      0.00e+00
# Error estándar:               0.0004
# Número de datos originales:   961167
# Puntos usados en regresión:   961167
# Amplitud mínima:              310.00
# Amplitud máxima:              43426.00
# Amplitud promedio:            3705.54
# Binning aplicado:             No
# ============================================================
# ✓ Excelente ajuste de la regresión
# ✓ Índice de masa calculado: s = 2.1561
# Gráfico guardado como: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\reports\figures\indice_masa_2024_20250608_013313.png
#
# ============================================================
# ANÁLISIS COMPLETADO - 1 períodos procesados
# ============================================================
#
# --- Amplitud mínima: 1.0 ---
# ============================================================
# INICIANDO ANÁLISIS DE ÍNDICE DE MASA DE METEORITOS
# ============================================================
# Tipo de archivo: CSV
# Período de análisis: anual
# Amplitud mínima: 1.0
#
# Cargando datos desde: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\data\processed\2024_consolidado.csv
# Datos CSV cargados: 961167 filas, 14 columnas
# Columnas disponibles: ['Date', 'Time', 'Rge', 'Ht', 'Vrad', 'delVr', 'Theta', 'Phi0', 'Delphase', 'ant-pair', 'amax', 'Tau', 'vmet', 'snrdb']
# Columna datetime creada exitosamente
# Datos agrupados por anual: 1 períodos
#
# --- Analizando período: 2024 ---
# Después del filtrado: 961167 valores
#
# ============================================================
# RESULTADOS DEL ANÁLISIS DE ÍNDICE DE MASA - 2024
# ============================================================
# Índice de masa (s):           2.1561
# Pendiente de regresión:       -1.1561
# Intercepto:                   9.4827
# Coeficiente de correlación:   -0.9499
# R² (bondad de ajuste):        0.9024
# P-value:                      0.00e+00
# Error estándar:               0.0004
# Número de datos originales:   961167
# Puntos usados en regresión:   961167
# Amplitud mínima:              310.00
# Amplitud máxima:              43426.00
# Amplitud promedio:            3705.54
# Binning aplicado:             No
# ============================================================
# ✓ Excelente ajuste de la regresión
# ✓ Índice de masa calculado: s = 2.1561
# Gráfico guardado como: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\reports\figures\indice_masa_2024_20250608_013357.png
#
# ============================================================
# ANÁLISIS COMPLETADO - 1 períodos procesados
# ============================================================
#
# --- Amplitud mínima: 2.0 ---
# ============================================================
# INICIANDO ANÁLISIS DE ÍNDICE DE MASA DE METEORITOS
# ============================================================
# Tipo de archivo: CSV
# Período de análisis: anual
# Amplitud mínima: 2.0
#
# Cargando datos desde: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\data\processed\2024_consolidado.csv
# Datos CSV cargados: 961167 filas, 14 columnas
# Columnas disponibles: ['Date', 'Time', 'Rge', 'Ht', 'Vrad', 'delVr', 'Theta', 'Phi0', 'Delphase', 'ant-pair', 'amax', 'Tau', 'vmet', 'snrdb']
# Columna datetime creada exitosamente
# Datos agrupados por anual: 1 períodos
#
# --- Analizando período: 2024 ---
# Después del filtrado: 961167 valores
#
# ============================================================
# RESULTADOS DEL ANÁLISIS DE ÍNDICE DE MASA - 2024
# ============================================================
# Índice de masa (s):           2.1561
# Pendiente de regresión:       -1.1561
# Intercepto:                   9.4827
# Coeficiente de correlación:   -0.9499
# R² (bondad de ajuste):        0.9024
# P-value:                      0.00e+00
# Error estándar:               0.0004
# Número de datos originales:   961167
# Puntos usados en regresión:   961167
# Amplitud mínima:              310.00
# Amplitud máxima:              43426.00
# Amplitud promedio:            3705.54
# Binning aplicado:             No
# ============================================================
# ✓ Excelente ajuste de la regresión
# ✓ Índice de masa calculado: s = 2.1561
# Gráfico guardado como: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\reports\figures\indice_masa_2024_20250608_013440.png
#
# ============================================================
# ANÁLISIS COMPLETADO - 1 períodos procesados
# ============================================================
#
# --- Amplitud mínima: 5.0 ---
# ============================================================
# INICIANDO ANÁLISIS DE ÍNDICE DE MASA DE METEORITOS
# ============================================================
# Tipo de archivo: CSV
# Período de análisis: anual
# Amplitud mínima: 5.0
#
# Cargando datos desde: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\data\processed\2024_consolidado.csv
# Datos CSV cargados: 961167 filas, 14 columnas
# Columnas disponibles: ['Date', 'Time', 'Rge', 'Ht', 'Vrad', 'delVr', 'Theta', 'Phi0', 'Delphase', 'ant-pair', 'amax', 'Tau', 'vmet', 'snrdb']
# Columna datetime creada exitosamente
# Datos agrupados por anual: 1 períodos
#
# --- Analizando período: 2024 ---
# Después del filtrado: 961167 valores
#
# ============================================================
# RESULTADOS DEL ANÁLISIS DE ÍNDICE DE MASA - 2024
# ============================================================
# Índice de masa (s):           2.1561
# Pendiente de regresión:       -1.1561
# Intercepto:                   9.4827
# Coeficiente de correlación:   -0.9499
# R² (bondad de ajuste):        0.9024
# P-value:                      0.00e+00
# Error estándar:               0.0004
# Número de datos originales:   961167
# Puntos usados en regresión:   961167
# Amplitud mínima:              310.00
# Amplitud máxima:              43426.00
# Amplitud promedio:            3705.54
# Binning aplicado:             No
# ============================================================
# ✓ Excelente ajuste de la regresión
# ✓ Índice de masa calculado: s = 2.1561
# Gráfico guardado como: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\reports\figures\indice_masa_2024_20250608_013523.png
#
# ============================================================
# ANÁLISIS COMPLETADO - 1 períodos procesados
# ============================================================
#
# --- Amplitud mínima: 10.0 ---
# ============================================================
# INICIANDO ANÁLISIS DE ÍNDICE DE MASA DE METEORITOS
# ============================================================
# Tipo de archivo: CSV
# Período de análisis: anual
# Amplitud mínima: 10.0
#
# Cargando datos desde: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\data\processed\2024_consolidado.csv
# Datos CSV cargados: 961167 filas, 14 columnas
# Columnas disponibles: ['Date', 'Time', 'Rge', 'Ht', 'Vrad', 'delVr', 'Theta', 'Phi0', 'Delphase', 'ant-pair', 'amax', 'Tau', 'vmet', 'snrdb']
# Columna datetime creada exitosamente
# Datos agrupados por anual: 1 períodos
#
# --- Analizando período: 2024 ---
# Después del filtrado: 961167 valores
#
# ============================================================
# RESULTADOS DEL ANÁLISIS DE ÍNDICE DE MASA - 2024
# ============================================================
# Índice de masa (s):           2.1561
# Pendiente de regresión:       -1.1561
# Intercepto:                   9.4827
# Coeficiente de correlación:   -0.9499
# R² (bondad de ajuste):        0.9024
# P-value:                      0.00e+00
# Error estándar:               0.0004
# Número de datos originales:   961167
# Puntos usados en regresión:   961167
# Amplitud mínima:              310.00
# Amplitud máxima:              43426.00
# Amplitud promedio:            3705.54
# Binning aplicado:             No
# ============================================================
# ✓ Excelente ajuste de la regresión
# ✓ Índice de masa calculado: s = 2.1561
# Gráfico guardado como: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\reports\figures\indice_masa_2024_20250608_013605.png
#
# ============================================================
# ANÁLISIS COMPLETADO - 1 períodos procesados
# ============================================================
#
# 🔍 ANÁLISIS: EFECTO DEL BINNING LOGARÍTMICO
# =============================================
#
# --- Sin binning ---
# ============================================================
# INICIANDO ANÁLISIS DE ÍNDICE DE MASA DE METEORITOS
# ============================================================
# Tipo de archivo: CSV
# Período de análisis: anual
#
# Cargando datos desde: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\data\processed\2024_consolidado.csv
# Datos CSV cargados: 961167 filas, 14 columnas
# Columnas disponibles: ['Date', 'Time', 'Rge', 'Ht', 'Vrad', 'delVr', 'Theta', 'Phi0', 'Delphase', 'ant-pair', 'amax', 'Tau', 'vmet', 'snrdb']
# Columna datetime creada exitosamente
# Datos agrupados por anual: 1 períodos
#
# --- Analizando período: 2024 ---
#
# ============================================================
# RESULTADOS DEL ANÁLISIS DE ÍNDICE DE MASA - 2024
# ============================================================
# Índice de masa (s):           2.1561
# Pendiente de regresión:       -1.1561
# Intercepto:                   9.4827
# Coeficiente de correlación:   -0.9499
# R² (bondad de ajuste):        0.9024
# P-value:                      0.00e+00
# Error estándar:               0.0004
# Número de datos originales:   961167
# Puntos usados en regresión:   961167
# Amplitud mínima:              310.00
# Amplitud máxima:              43426.00
# Amplitud promedio:            3705.54
# Binning aplicado:             No
# ============================================================
# ✓ Excelente ajuste de la regresión
# ✓ Índice de masa calculado: s = 2.1561
#
# ============================================================
# ANÁLISIS COMPLETADO - 1 períodos procesados
# ============================================================
#
# --- Binning 25 ---
# ============================================================
# INICIANDO ANÁLISIS DE ÍNDICE DE MASA DE METEORITOS
# ============================================================
# Tipo de archivo: CSV
# Período de análisis: anual
# Binning logarítmico: 25 bins
#
# Cargando datos desde: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\data\processed\2024_consolidado.csv
# Datos CSV cargados: 961167 filas, 14 columnas
# Columnas disponibles: ['Date', 'Time', 'Rge', 'Ht', 'Vrad', 'delVr', 'Theta', 'Phi0', 'Delphase', 'ant-pair', 'amax', 'Tau', 'vmet', 'snrdb']
# Columna datetime creada exitosamente
# Datos agrupados por anual: 1 períodos
#
# --- Analizando período: 2024 ---
# Aplicando binning logarítmico con 25 bins...
#
# ============================================================
# RESULTADOS DEL ANÁLISIS DE ÍNDICE DE MASA - 2024
# ============================================================
# Índice de masa (s):           0.9873
# Pendiente de regresión:       0.0127
# Intercepto:                   4.1060
# Coeficiente de correlación:   0.0082
# R² (bondad de ajuste):        0.0001
# P-value:                      9.69e-01
# Error estándar:               0.3228
# Número de datos originales:   961167
# Puntos usados en regresión:   25
# Amplitud mínima:              310.00
# Amplitud máxima:              43426.00
# Amplitud promedio:            3705.54
# Binning aplicado:             Sí
# ============================================================
# ⚠ Ajuste de regresión podría mejorarse
# ✓ Índice de masa calculado: s = 0.9873
#
# ============================================================
# ANÁLISIS COMPLETADO - 1 períodos procesados
# ============================================================
#
# --- Binning 50 ---
# ============================================================
# INICIANDO ANÁLISIS DE ÍNDICE DE MASA DE METEORITOS
# ============================================================
# Tipo de archivo: CSV
# Período de análisis: anual
# Binning logarítmico: 50 bins
#
# Cargando datos desde: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\data\processed\2024_consolidado.csv
# Datos CSV cargados: 961167 filas, 14 columnas
# Columnas disponibles: ['Date', 'Time', 'Rge', 'Ht', 'Vrad', 'delVr', 'Theta', 'Phi0', 'Delphase', 'ant-pair', 'amax', 'Tau', 'vmet', 'snrdb']
# Columna datetime creada exitosamente
# Datos agrupados por anual: 1 períodos
#
# --- Analizando período: 2024 ---
# Aplicando binning logarítmico con 50 bins...
#
# ============================================================
# RESULTADOS DEL ANÁLISIS DE ÍNDICE DE MASA - 2024
# ============================================================
# Índice de masa (s):           0.9797
# Pendiente de regresión:       0.0203
# Intercepto:                   3.7610
# Coeficiente de correlación:   0.0127
# R² (bondad de ajuste):        0.0002
# P-value:                      9.30e-01
# Error estándar:               0.2305
# Número de datos originales:   961167
# Puntos usados en regresión:   50
# Amplitud mínima:              310.00
# Amplitud máxima:              43426.00
# Amplitud promedio:            3705.54
# Binning aplicado:             Sí
# ============================================================
# ⚠ Ajuste de regresión podría mejorarse
# ✓ Índice de masa calculado: s = 0.9797
#
# ============================================================
# ANÁLISIS COMPLETADO - 1 períodos procesados
# ============================================================
#
# --- Binning 100 ---
# ============================================================
# INICIANDO ANÁLISIS DE ÍNDICE DE MASA DE METEORITOS
# ============================================================
# Tipo de archivo: CSV
# Período de análisis: anual
# Binning logarítmico: 100 bins
#
# Cargando datos desde: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\data\processed\2024_consolidado.csv
# Datos CSV cargados: 961167 filas, 14 columnas
# Columnas disponibles: ['Date', 'Time', 'Rge', 'Ht', 'Vrad', 'delVr', 'Theta', 'Phi0', 'Delphase', 'ant-pair', 'amax', 'Tau', 'vmet', 'snrdb']
# Columna datetime creada exitosamente
# Datos agrupados por anual: 1 períodos
#
# --- Analizando período: 2024 ---
# Aplicando binning logarítmico con 100 bins...
#
# ============================================================
# RESULTADOS DEL ANÁLISIS DE ÍNDICE DE MASA - 2024
# ============================================================
# Índice de masa (s):           1.0712
# Pendiente de regresión:       -0.0712
# Intercepto:                   3.8161
# Coeficiente de correlación:   -0.0463
# R² (bondad de ajuste):        0.0021
# P-value:                      6.49e-01
# Error estándar:               0.1559
# Número de datos originales:   961167
# Puntos usados en regresión:   99
# Amplitud mínima:              310.00
# Amplitud máxima:              43426.00
# Amplitud promedio:            3705.54
# Binning aplicado:             Sí
# ============================================================
# ⚠ Ajuste de regresión podría mejorarse
# ✓ Índice de masa calculado: s = 1.0712
#
# ============================================================
# ANÁLISIS COMPLETADO - 1 períodos procesados
# ============================================================
# 📅 ANÁLISIS TEMPORAL - POR MESES
# ===================================
# ============================================================
# INICIANDO ANÁLISIS DE ÍNDICE DE MASA DE METEORITOS
# ============================================================
# Tipo de archivo: CSV
# Período de análisis: mensual
#
# Cargando datos desde: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\data\processed\2024_consolidado.csv
# Datos CSV cargados: 961167 filas, 14 columnas
# Columnas disponibles: ['Date', 'Time', 'Rge', 'Ht', 'Vrad', 'delVr', 'Theta', 'Phi0', 'Delphase', 'ant-pair', 'amax', 'Tau', 'vmet', 'snrdb']
# Columna datetime creada exitosamente
# Datos agrupados por mensual: 12 períodos
#
# --- Analizando período: Enero ---
#
# ============================================================
# RESULTADOS DEL ANÁLISIS DE ÍNDICE DE MASA - Enero
# ============================================================
# Índice de masa (s):           2.1648
# Pendiente de regresión:       -1.1648
# Intercepto:                   8.7274
# Coeficiente de correlación:   -0.9540
# R² (bondad de ajuste):        0.9101
# P-value:                      0.00e+00
# Error estándar:               0.0009
# Número de datos originales:   148575
# Puntos usados en regresión:   148575
# Amplitud mínima:              387.00
# Amplitud máxima:              42369.00
# Amplitud promedio:            3914.78
# Binning aplicado:             No
# ============================================================
# ✓ Excelente ajuste de la regresión
# ✓ Índice de masa calculado: s = 2.1648
# Resultados guardados en: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\reports\indice_masa_Enero_20250608_013708.txt
# Gráfico guardado como: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\reports\figures\indice_masa_Enero_20250608_013710.png
#
# --- Analizando período: Febrero ---
#
# ============================================================
# RESULTADOS DEL ANÁLISIS DE ÍNDICE DE MASA - Febrero
# ============================================================
# Índice de masa (s):           2.1602
# Pendiente de regresión:       -1.1602
# Intercepto:                   8.5803
# Coeficiente de correlación:   -0.9558
# R² (bondad de ajuste):        0.9135
# P-value:                      0.00e+00
# Error estándar:               0.0010
# Número de datos originales:   119819
# Puntos usados en regresión:   119819
# Amplitud mínima:              369.00
# Amplitud máxima:              41567.00
# Amplitud promedio:            3657.32
# Binning aplicado:             No
# ============================================================
# ✓ Excelente ajuste de la regresión
# ✓ Índice de masa calculado: s = 2.1602
# Resultados guardados en: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\reports\indice_masa_Febrero_20250608_013715.txt
# Gráfico guardado como: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\reports\figures\indice_masa_Febrero_20250608_013717.png
#
# --- Analizando período: Marzo ---
#
# ============================================================
# RESULTADOS DEL ANÁLISIS DE ÍNDICE DE MASA - Marzo
# ============================================================
# Índice de masa (s):           2.1740
# Pendiente de regresión:       -1.1740
# Intercepto:                   8.3907
# Coeficiente de correlación:   -0.9482
# R² (bondad de ajuste):        0.8992
# P-value:                      0.00e+00
# Error estándar:               0.0015
# Número de datos originales:   69321
# Puntos usados en regresión:   69321
# Amplitud mínima:              414.00
# Amplitud máxima:              40172.00
# Amplitud promedio:            3566.99
# Binning aplicado:             No
# ============================================================
# ✓ Excelente ajuste de la regresión
# ✓ Índice de masa calculado: s = 2.1740
# Resultados guardados en: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\reports\indice_masa_Marzo_20250608_013722.txt
# Gráfico guardado como: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\reports\figures\indice_masa_Marzo_20250608_013723.png
#
# --- Analizando período: Abril ---
#
# ============================================================
# RESULTADOS DEL ANÁLISIS DE ÍNDICE DE MASA - Abril
# ============================================================
# Índice de masa (s):           2.1485
# Pendiente de regresión:       -1.1485
# Intercepto:                   8.2624
# Coeficiente de correlación:   -0.9421
# R² (bondad de ajuste):        0.8875
# P-value:                      0.00e+00
# Error estándar:               0.0017
# Número de datos originales:   58464
# Puntos usados en regresión:   58464
# Amplitud mínima:              390.00
# Amplitud máxima:              40557.00
# Amplitud promedio:            3814.96
# Binning aplicado:             No
# ============================================================
# ✓ Excelente ajuste de la regresión
# ✓ Índice de masa calculado: s = 2.1485
# Resultados guardados en: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\reports\indice_masa_Abril_20250608_013727.txt
# Gráfico guardado como: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\reports\figures\indice_masa_Abril_20250608_013728.png
#
# --- Analizando período: Mayo ---
#
# ============================================================
# RESULTADOS DEL ANÁLISIS DE ÍNDICE DE MASA - Mayo
# ============================================================
# Índice de masa (s):           2.1373
# Pendiente de regresión:       -1.1373
# Intercepto:                   8.2698
# Coeficiente de correlación:   -0.9386
# R² (bondad de ajuste):        0.8809
# P-value:                      0.00e+00
# Error estándar:               0.0016
# Número de datos originales:   64625
# Puntos usados en regresión:   64625
# Amplitud mínima:              408.00
# Amplitud máxima:              37221.00
# Amplitud promedio:            3835.04
# Binning aplicado:             No
# ============================================================
# ✓ Excelente ajuste de la regresión
# ✓ Índice de masa calculado: s = 2.1373
# Resultados guardados en: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\reports\indice_masa_Mayo_20250608_013731.txt
# Gráfico guardado como: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\reports\figures\indice_masa_Mayo_20250608_013733.png
#
# --- Analizando período: Junio ---
#
# ============================================================
# RESULTADOS DEL ANÁLISIS DE ÍNDICE DE MASA - Junio
# ============================================================
# Índice de masa (s):           2.1509
# Pendiente de regresión:       -1.1509
# Intercepto:                   8.2702
# Coeficiente de correlación:   -0.9411
# R² (bondad de ajuste):        0.8856
# P-value:                      0.00e+00
# Error estándar:               0.0017
# Número de datos originales:   60229
# Puntos usados en regresión:   60229
# Amplitud mínima:              365.00
# Amplitud máxima:              37898.00
# Amplitud promedio:            3703.63
# Binning aplicado:             No
# ============================================================
# ✓ Excelente ajuste de la regresión
# ✓ Índice de masa calculado: s = 2.1509
# Resultados guardados en: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\reports\indice_masa_Junio_20250608_013736.txt
# Gráfico guardado como: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\reports\figures\indice_masa_Junio_20250608_013738.png
#
# --- Analizando período: Julio ---
#
# ============================================================
# RESULTADOS DEL ANÁLISIS DE ÍNDICE DE MASA - Julio
# ============================================================
# Índice de masa (s):           2.1604
# Pendiente de regresión:       -1.1604
# Intercepto:                   8.3841
# Coeficiente de correlación:   -0.9478
# R² (bondad de ajuste):        0.8983
# P-value:                      0.00e+00
# Error estándar:               0.0014
# Número de datos originales:   74025
# Puntos usados en regresión:   74025
# Amplitud mínima:              384.00
# Amplitud máxima:              43426.00
# Amplitud promedio:            3678.45
# Binning aplicado:             No
# ============================================================
# ✓ Excelente ajuste de la regresión
# ✓ Índice de masa calculado: s = 2.1604
# Resultados guardados en: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\reports\indice_masa_Julio_20250608_013741.txt
# Gráfico guardado como: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\reports\figures\indice_masa_Julio_20250608_013742.png
#
# --- Analizando período: Agosto ---
#
# ============================================================
# RESULTADOS DEL ANÁLISIS DE ÍNDICE DE MASA - Agosto
# ============================================================
# Índice de masa (s):           2.1674
# Pendiente de regresión:       -1.1674
# Intercepto:                   8.2437
# Coeficiente de correlación:   -0.9533
# R² (bondad de ajuste):        0.9087
# P-value:                      0.00e+00
# Error estándar:               0.0015
# Número de datos originales:   58599
# Puntos usados en regresión:   58599
# Amplitud mínima:              380.00
# Amplitud máxima:              40315.00
# Amplitud promedio:            3270.23
# Binning aplicado:             No
# ============================================================
# ✓ Excelente ajuste de la regresión
# ✓ Índice de masa calculado: s = 2.1674
# Resultados guardados en: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\reports\indice_masa_Agosto_20250608_013746.txt
# Gráfico guardado como: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\reports\figures\indice_masa_Agosto_20250608_013747.png
#
# --- Analizando período: Septiembre ---
#
# ============================================================
# RESULTADOS DEL ANÁLISIS DE ÍNDICE DE MASA - Septiembre
# ============================================================
# Índice de masa (s):           2.1848
# Pendiente de regresión:       -1.1848
# Intercepto:                   8.1894
# Coeficiente de correlación:   -0.9394
# R² (bondad de ajuste):        0.8825
# P-value:                      0.00e+00
# Error estándar:               0.0024
# Número de datos originales:   33456
# Puntos usados en regresión:   33456
# Amplitud mínima:              376.00
# Amplitud máxima:              39528.00
# Amplitud promedio:            4055.17
# Binning aplicado:             No
# ============================================================
# ✓ Excelente ajuste de la regresión
# ✓ Índice de masa calculado: s = 2.1848
# Resultados guardados en: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\reports\indice_masa_Septiembre_20250608_013750.txt
# Gráfico guardado como: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\reports\figures\indice_masa_Septiembre_20250608_013752.png
#
# --- Analizando período: Octubre ---
#
# ============================================================
# RESULTADOS DEL ANÁLISIS DE ÍNDICE DE MASA - Octubre
# ============================================================
# Índice de masa (s):           2.1641
# Pendiente de regresión:       -1.1641
# Intercepto:                   8.1421
# Coeficiente de correlación:   -0.9457
# R² (bondad de ajuste):        0.8944
# P-value:                      0.00e+00
# Error estándar:               0.0020
# Número de datos originales:   39765
# Puntos usados en regresión:   39765
# Amplitud mínima:              380.00
# Amplitud máxima:              39769.00
# Amplitud promedio:            3758.83
# Binning aplicado:             No
# ============================================================
# ✓ Excelente ajuste de la regresión
# ✓ Índice de masa calculado: s = 2.1641
# Resultados guardados en: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\reports\indice_masa_Octubre_20250608_013754.txt
# Gráfico guardado como: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\reports\figures\indice_masa_Octubre_20250608_013755.png
#
# --- Analizando período: Noviembre ---
#
# ============================================================
# RESULTADOS DEL ANÁLISIS DE ÍNDICE DE MASA - Noviembre
# ============================================================
# Índice de masa (s):           2.1566
# Pendiente de regresión:       -1.1566
# Intercepto:                   8.4668
# Coeficiente de correlación:   -0.9506
# R² (bondad de ajuste):        0.9036
# P-value:                      0.00e+00
# Error estándar:               0.0013
# Número de datos originales:   85304
# Puntos usados en regresión:   85304
# Amplitud mínima:              381.00
# Amplitud máxima:              42373.00
# Amplitud promedio:            3973.98
# Binning aplicado:             No
# ============================================================
# ✓ Excelente ajuste de la regresión
# ✓ Índice de masa calculado: s = 2.1566
# Resultados guardados en: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\reports\indice_masa_Noviembre_20250608_013758.txt
# Gráfico guardado como: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\reports\figures\indice_masa_Noviembre_20250608_013800.png
#
# --- Analizando período: Diciembre ---
#
# ============================================================
# RESULTADOS DEL ANÁLISIS DE ÍNDICE DE MASA - Diciembre
# ============================================================
# Índice de masa (s):           2.1556
# Pendiente de regresión:       -1.1556
# Intercepto:                   8.6245
# Coeficiente de correlación:   -0.9576
# R² (bondad de ajuste):        0.9170
# P-value:                      0.00e+00
# Error estándar:               0.0009
# Número de datos originales:   148985
# Puntos usados en regresión:   148985
# Amplitud mínima:              310.00
# Amplitud máxima:              40990.00
# Amplitud promedio:            3439.99
# Binning aplicado:             No
# ============================================================
# ✓ Excelente ajuste de la regresión
# ✓ Índice de masa calculado: s = 2.1556
# Resultados guardados en: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\reports\indice_masa_Diciembre_20250608_013803.txt
# Gráfico guardado como: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\reports\figures\indice_masa_Diciembre_20250608_013806.png
#
# ============================================================
# ANÁLISIS COMPLETADO - 12 períodos procesados
# ============================================================
# 📅 ANÁLISIS TEMPORAL - POR TRIMESTRES
# ======================================
# ============================================================
# INICIANDO ANÁLISIS DE ÍNDICE DE MASA DE METEORITOS
# ============================================================
# Tipo de archivo: CSV
# Período de análisis: trimestral
#
# Cargando datos desde: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\data\processed\2024_consolidado.csv
# Datos CSV cargados: 961167 filas, 14 columnas
# Columnas disponibles: ['Date', 'Time', 'Rge', 'Ht', 'Vrad', 'delVr', 'Theta', 'Phi0', 'Delphase', 'ant-pair', 'amax', 'Tau', 'vmet', 'snrdb']
# Columna datetime creada exitosamente
# Datos agrupados por trimestral: 4 períodos
#
# --- Analizando período: Trimestre_1 ---
#
# ============================================================
# RESULTADOS DEL ANÁLISIS DE ÍNDICE DE MASA - Trimestre_1
# ============================================================
# Índice de masa (s):           2.1641
# Pendiente de regresión:       -1.1641
# Intercepto:                   9.0604
# Coeficiente de correlación:   -0.9534
# R² (bondad de ajuste):        0.9090
# P-value:                      0.00e+00
# Error estándar:               0.0006
# Número de datos originales:   337715
# Puntos usados en regresión:   337715
# Amplitud mínima:              369.00
# Amplitud máxima:              42369.00
# Amplitud promedio:            3752.05
# Binning aplicado:             No
# ============================================================
# ✓ Excelente ajuste de la regresión
# ✓ Índice de masa calculado: s = 2.1641
# Resultados guardados en: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\reports\indice_masa_Trimestre_1_20250608_013819.txt
#
# --- Analizando período: Trimestre_2 ---
#
# ============================================================
# RESULTADOS DEL ANÁLISIS DE ÍNDICE DE MASA - Trimestre_2
# ============================================================
# Índice de masa (s):           2.1454
# Pendiente de regresión:       -1.1454
# Intercepto:                   8.7444
# Coeficiente de correlación:   -0.9404
# R² (bondad de ajuste):        0.8843
# P-value:                      0.00e+00
# Error estándar:               0.0010
# Número de datos originales:   183318
# Puntos usados en regresión:   183318
# Amplitud mínima:              365.00
# Amplitud máxima:              40557.00
# Amplitud promedio:            3785.46
# Binning aplicado:             No
# ============================================================
# ✓ Excelente ajuste de la regresión
# ✓ Índice de masa calculado: s = 2.1454
# Resultados guardados en: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\reports\indice_masa_Trimestre_2_20250608_013819.txt
#
# --- Analizando período: Trimestre_3 ---
#
# ============================================================
# RESULTADOS DEL ANÁLISIS DE ÍNDICE DE MASA - Trimestre_3
# ============================================================
# Índice de masa (s):           2.1592
# Pendiente de regresión:       -1.1592
# Intercepto:                   8.7221
# Coeficiente de correlación:   -0.9469
# R² (bondad de ajuste):        0.8967
# P-value:                      0.00e+00
# Error estándar:               0.0010
# Número de datos originales:   166080
# Puntos usados en regresión:   166080
# Amplitud mínima:              376.00
# Amplitud máxima:              43426.00
# Amplitud promedio:            3610.30
# Binning aplicado:             No
# ============================================================
# ✓ Excelente ajuste de la regresión
# ✓ Índice de masa calculado: s = 2.1592
# Resultados guardados en: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\reports\indice_masa_Trimestre_3_20250608_013819.txt
#
# --- Analizando período: Trimestre_4 ---
#
# ============================================================
# RESULTADOS DEL ANÁLISIS DE ÍNDICE DE MASA - Trimestre_4
# ============================================================
# Índice de masa (s):           2.1519
# Pendiente de regresión:       -1.1519
# Intercepto:                   8.9107
# Coeficiente de correlación:   -0.9531
# R² (bondad de ajuste):        0.9085
# P-value:                      0.00e+00
# Error estándar:               0.0007
# Número de datos originales:   274054
# Puntos usados en regresión:   274054
# Amplitud mínima:              310.00
# Amplitud máxima:              42373.00
# Amplitud promedio:            3652.47
# Binning aplicado:             No
# ============================================================
# ✓ Excelente ajuste de la regresión
# ✓ Índice de masa calculado: s = 2.1519
# Resultados guardados en: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\reports\indice_masa_Trimestre_4_20250608_013819.txt
#
# ============================================================
# ANÁLISIS COMPLETADO - 4 períodos procesados
# ============================================================
#
# 📋 RESUMEN TRIMESTRAL:
# ----------------------------------------------------------------------
# Trimestre    N_datos  Índice_s   R²       P-value
# ----------------------------------------------------------------------
# Trimestre_1  337715   2.1641     0.9090   0.00e+00
# Trimestre_2  183318   2.1454     0.8843   0.00e+00
# Trimestre_3  166080   2.1592     0.8967   0.00e+00
# Trimestre_4  274054   2.1519     0.9085   0.00e+00
# 📝 RESUMEN DEL ANÁLISIS
# =========================
# ✅ RESULTADO PRINCIPAL:
#    • Índice de masa calculado: s = 2.1561
#    • Calidad del ajuste (R²): 0.9024
#    • Número de datos utilizados: 961167
#    • Rango de amplitudes: 310.00 - 43426.00
#
# 📂 ARCHIVOS GENERADOS:
#    • Resultados guardados en: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\reports
#    • Gráficos guardados en: D:\ESTUDIO\CPMA\VSC - TECNICATURA\PP1\PP1_Astronomica_I_-IM\reports\figures
#
# 🔬 PRÓXIMOS PASOS SUGERIDOS:
#    1. Revisar la calidad del ajuste (R² > 0.8 es excelente)
#    2. Comparar resultados con diferentes filtros de amplitud
#    3. Analizar variabilidad temporal si es relevante
#    4. Considerar análisis de sensibilidad a parámetros
#    5. Validar resultados con literatura científica
#
# 💡 NOTAS:
#    • El índice de masa típico para meteoritos está entre 1.5-2.5
#    • Valores de R² > 0.8 indican un buen ajuste al modelo potencial
#    • El binning puede mejorar el ajuste pero reduce la resolución
